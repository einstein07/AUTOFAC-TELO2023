# %%
import random
print("starting...")
line = ""
x = 0
y = 0
isOv = True
x_p = []
y_p = []
for i in range(101):
    while(isOv):
        x = round(random.uniform(-9.7, 9.7),1)
        y = round(random.uniform(-7.5, 9.7),1)
        x_min = x - 0.1
        x_max = x + 0.1
        y_min = y - 0.1
        y_max = y + 0.1
        isCheck = True
        for j in range(len(x_p)):
            inrange_x = False
            inrange_y = False;
            if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                inrange_x = True
            if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                inrange_y = True
            if (inrange_y and inrange_x):
                isCheck = False;
                break;
        if (isCheck == True):
            x_p.append(x)
            y_p.append(y)
            break
        
    line = line + str(x) + " " + str(y) + " 0\n"
line = line.rstrip("\n")
print (line)
f = open("robotStartPositions5.txt", "w")
f.write(line)
f.close()
print ("done")
# Out:
# starting...
# 1.0 1.7 0
# -6.4 -2.6 0
# 8.9 -0.4 0
# -4.0 -0.2 0
# -6.9 5.6 0
# 7.4 4.8 0
# 4.4 -0.5 0
# -0.7 -6.2 0
# -6.4 6.1 0
# -0.0 4.0 0
# 5.2 -2.0 0
# 5.9 -2.9 0
# 2.8 -4.1 0
# -7.4 8.2 0
# 3.1 1.6 0
# -2.0 -0.1 0
# -5.7 -0.0 0
# -4.7 -1.2 0
# 5.3 -1.5 0
# -4.6 -6.4 0
# -3.9 -1.8 0
# -9.6 2.1 0
# -8.5 6.4 0
# -4.6 8.6 0
# -3.3 -2.2 0
# -0.6 5.2 0
# 5.6 7.5 0
# 5.4 -2.1 0
# -4.0 -1.0 0
# -8.7 -6.3 0
# 8.1 -1.7 0
# -7.3 4.2 0
# 8.6 -0.5 0
# -4.9 -0.5 0
# -0.3 5.0 0
# 8.6 1.5 0
# 3.3 0.2 0
# 3.4 7.6 0
# -3.5 0.8 0
# -8.8 1.4 0
# -2.0 -5.6 0
# -5.5 -0.1 0
# 4.4 -4.4 0
# -0.5 -7.2 0
# -7.2 -5.4 0
# 2.1 9.4 0
# 3.1 -6.7 0
# -8.9 -4.0 0
# -4.7 9.2 0
# 8.8 -6.5 0
# -3.9 5.7 0
# 2.3 4.4 0
# -9.3 -5.7 0
# -0.8 9.0 0
# -9.5 0.2 0
# -4.3 -5.4 0
# 8.0 -2.9 0
# -6.5 -7.3 0
# 3.7 -7.2 0
# -8.9 -3.5 0
# -8.9 4.3 0
# -0.6 -3.2 0
# 5.1 -1.0 0
# 7.6 9.4 0
# -2.5 5.7 0
# 4.9 -6.2 0
# 1.9 -3.9 0
# 0.7 -4.0 0
# -1.5 -1.2 0
# 3.3 -7.2 0
# 0.3 -2.2 0
# -2.8 -6.3 0
# -5.7 3.6 0
# 1.8 -6.5 0
# ...

# %%
#ENVIRONMENT TYPE 1
# type-1-resources: 20 type-2-resources: 20 type-3-resources: 10 
import random
print("Resources positions: starting...")
line = ""
x = 0
y = 0
isOv = True
typeCounter = 1
for i in range( 1, 51 ):
    
    while(isOv):
        x = round(random.uniform(-9.5, 9.5),1)
        y = round(random.uniform(-7.5, 9.5),1)
        if (typeCounter == 1):
            x_min = x - 0.04
            x_max = x + 0.04
            y_min = y - 0.04
            y_max = y + 0.04
        if (typeCounter == 2):
            x_min = x - 0.25
            x_max = x + 0.25
            y_min = y - 0.25
            y_max = y + 0.25
        if (typeCounter == 3):
            x_min = x - 0.45
            x_max = x + 0.45
            y_min = y - 0.45
            y_max = y + 0.45
        if (typeCounter == 4):
            x_min = x - 0.45
            x_max = x + 0.45
            y_min = y - 0.45
            y_max = y + 0.45
        if (typeCounter == 5):
            x = round(random.uniform(-9.2, 9.2),1)
            y = round(random.uniform(-4.5, 9.2),1)
            x_min = x - 0.6
            x_max = x + 0.6
            y_min = y - 0.6
            y_max = y + 0.6
        isCheck = True
        for j in range(len(x_p)):
            inrange_x = False
            inrange_y = False;
            if (j < 100):
                if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                    inrange_x = True
                if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                    inrange_y = True
            else:
                if (((x_p[j]-0.5) <= x_min and (x_p[j] + 0.5) >= x_max) or ((x_p[j]-0.5) >= x_min and (x_p[j] - 0.5) <= x_max) or ((x_p[j]+0.5) >= x_min and (x_p[j] + 0.5) <= x_max) ):
                    inrange_x = True
                if (((y_p[j]-0.5) <= y_min and (y_p[j] + 0.5) >= y_max) or ((y_p[j]-0.5) >= y_min and (y_p[j] - 0.5) <= y_max) or ((y_p[j]+0.5) >= y_min and (y_p[j] + 0.5) <= y_max) ):
                    inrange_y = True
            if (inrange_y and inrange_x):
                isCheck = False;
                break;
        if (isCheck == True):
            x_p.append(x)
            y_p.append(y)
            break
    if (typeCounter == 1):
        line = line + str(x) + " " + str(y) + " 0.05 0.08 0.08 0.08 0.002 " + str(typeCounter)+ "\n"
    if (typeCounter == 2):
        line = line + str(x) + " " + str(y) + " 0.05 0.5 0.5 0.08 0.8 " + str(typeCounter)+ "\n"
    if (typeCounter == 3):
        line = line + str(x) + " " + str(y) + " 0.05 0.8 0.8 0.08 1 " + str(typeCounter)+ "\n"
    if (typeCounter == 4):
        line = line + str(x) + " " + str(y) + " 0.05 1 1 0.08 1.2 " + str(typeCounter)+ "\n"
    if (typeCounter == 5):
        line = line + str(x) + " " + str(y) + " 0.05 1.2 1.2 0.08 1.4 " + str(typeCounter)+ "\n"
    if (typeCounter == 1 and i%30 == 0):
        typeCounter = typeCounter+1
    if (typeCounter != 1 and i%5 == 0 and i != 30):
        typeCounter = typeCounter+1
line = line.rstrip("\n")
print (line)
f = open("resources-environment-1-run-4.txt", "w")
f.write(line)
f.close()
print ("done")
# Out:
# Resources positions: starting...
# 9.0 1.4 0.05 0.08 0.08 0.08 0.002 1
# 8.1 1.6 0.05 0.08 0.08 0.08 0.002 1
# 2.2 9.4 0.05 0.08 0.08 0.08 0.002 1
# 2.8 3.6 0.05 0.08 0.08 0.08 0.002 1
# -4.0 3.3 0.05 0.08 0.08 0.08 0.002 1
# -3.6 5.5 0.05 0.08 0.08 0.08 0.002 1
# 8.5 9.2 0.05 0.08 0.08 0.08 0.002 1
# 6.6 -2.3 0.05 0.08 0.08 0.08 0.002 1
# -3.0 3.4 0.05 0.08 0.08 0.08 0.002 1
# -0.3 6.4 0.05 0.08 0.08 0.08 0.002 1
# -1.1 -7.3 0.05 0.08 0.08 0.08 0.002 1
# -4.2 9.1 0.05 0.08 0.08 0.08 0.002 1
# 3.6 2.5 0.05 0.08 0.08 0.08 0.002 1
# 3.3 6.8 0.05 0.08 0.08 0.08 0.002 1
# 5.9 -2.7 0.05 0.08 0.08 0.08 0.002 1
# -3.6 2.6 0.05 0.08 0.08 0.08 0.002 1
# -2.0 -3.9 0.05 0.08 0.08 0.08 0.002 1
# 3.5 4.8 0.05 0.08 0.08 0.08 0.002 1
# -3.1 -3.5 0.05 0.08 0.08 0.08 0.002 1
# -8.8 7.8 0.05 0.08 0.08 0.08 0.002 1
# 2.7 1.9 0.05 0.08 0.08 0.08 0.002 1
# -7.8 4.2 0.05 0.08 0.08 0.08 0.002 1
# -0.1 0.5 0.05 0.08 0.08 0.08 0.002 1
# -2.1 2.0 0.05 0.08 0.08 0.08 0.002 1
# ...

# %%
#ENVIRONMENT TYPE 2
# type-1-resources: 10 type-2-resources: 10 type-3-resources: 10 type-4-resources: 10 type-5-resources: 10 
import random
print("Resources positions: starting...")
line = ""
x = 0
y = 0
isOv = True
typeCounter = 1
for i in range( 1, 51 ):
    
    while(isOv):
        x = round(random.uniform(-9.5, 9.5),1)
        y = round(random.uniform(-7.5, 9.5),1)
        if (typeCounter == 1):
            x_min = x - 0.04
            x_max = x + 0.04
            y_min = y - 0.04
            y_max = y + 0.04
        if (typeCounter == 2):
            x_min = x - 0.25
            x_max = x + 0.25
            y_min = y - 0.25
            y_max = y + 0.25
        if (typeCounter == 3):
            x_min = x - 0.45
            x_max = x + 0.45
            y_min = y - 0.45
            y_max = y + 0.45
        if (typeCounter == 4):
            x_min = x - 0.45
            x_max = x + 0.45
            y_min = y - 0.45
            y_max = y + 0.45
        if (typeCounter == 5):
            x = round(random.uniform(-9.2, 9.2),1)
            y = round(random.uniform(-7.5, 9.2),1)
            x_min = x - 0.6
            x_max = x + 0.6
            y_min = y - 0.6
            y_max = y + 0.6
        isCheck = True
        for j in range(len(x_p)):
            inrange_x = False
            inrange_y = False;
            if (j < 100):
                if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                    inrange_x = True
                if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                    inrange_y = True
            else:
                if (((x_p[j]-0.5) <= x_min and (x_p[j] + 0.5) >= x_max) or ((x_p[j]-0.5) >= x_min and (x_p[j] - 0.5) <= x_max) or ((x_p[j]+0.5) >= x_min and (x_p[j] + 0.5) <= x_max) ):
                    inrange_x = True
                if (((y_p[j]-0.5) <= y_min and (y_p[j] + 0.5) >= y_max) or ((y_p[j]-0.5) >= y_min and (y_p[j] - 0.5) <= y_max) or ((y_p[j]+0.5) >= y_min and (y_p[j] + 0.5) <= y_max) ):
                    inrange_y = True
            if (inrange_y and inrange_x):
                isCheck = False;
                break;
        if (isCheck == True):
            x_p.append(x)
            y_p.append(y)
            break
    if (typeCounter == 1):
        line = line + str(x) + " " + str(y) + " 0.05 0.08 0.08 0.08 0.002 " + str(typeCounter)+ "\n"
    if (typeCounter == 2):
        line = line + str(x) + " " + str(y) + " 0.05 0.5 0.5 0.08 0.8 " + str(typeCounter)+ "\n"
    if (typeCounter == 3):
        line = line + str(x) + " " + str(y) + " 0.05 0.8 0.8 0.08 1 " + str(typeCounter)+ "\n"
    if (typeCounter == 4):
        line = line + str(x) + " " + str(y) + " 0.05 1 1 0.08 1.2 " + str(typeCounter)+ "\n"
    if (typeCounter == 5):
        line = line + str(x) + " " + str(y) + " 0.05 1.2 1.2 0.08 1.4 " + str(typeCounter)+ "\n"
    if (i%10 == 0):
        typeCounter = typeCounter+1
line = line.rstrip("\n")
print (line)
f = open("resources-environment-2.txt", "w")
f.write(line)
f.close()
print ("done")
# Out:
# Resources positions: starting...
# -1.8 4.2 0.05 0.08 0.08 0.08 0.002 1
# -2.9 -2.3 0.05 0.08 0.08 0.08 0.002 1
# 5.1 2.1 0.05 0.08 0.08 0.08 0.002 1
# -9.0 3.9 0.05 0.08 0.08 0.08 0.002 1
# -2.1 5.0 0.05 0.08 0.08 0.08 0.002 1
# 4.6 -3.8 0.05 0.08 0.08 0.08 0.002 1
# 4.6 1.4 0.05 0.08 0.08 0.08 0.002 1
# -8.8 -5.2 0.05 0.08 0.08 0.08 0.002 1
# -1.1 -6.6 0.05 0.08 0.08 0.08 0.002 1
# -3.4 -5.1 0.05 0.08 0.08 0.08 0.002 1
# 1.1 3.4 0.05 0.5 0.5 0.08 0.8 2
# 7.3 -3.8 0.05 0.5 0.5 0.08 0.8 2
# 1.6 0.0 0.05 0.5 0.5 0.08 0.8 2
# -7.2 -0.8 0.05 0.5 0.5 0.08 0.8 2
# 2.5 4.5 0.05 0.5 0.5 0.08 0.8 2
# 1.3 -6.6 0.05 0.5 0.5 0.08 0.8 2
# -9.2 -1.1 0.05 0.5 0.5 0.08 0.8 2
# -2.8 9.1 0.05 0.5 0.5 0.08 0.8 2
# 3.3 -7.0 0.05 0.5 0.5 0.08 0.8 2
# 4.1 7.6 0.05 0.5 0.5 0.08 0.8 2
# -5.1 0.8 0.05 0.8 0.8 0.08 1 3
# 8.6 -0.0 0.05 0.8 0.8 0.08 1 3
# 7.3 -6.6 0.05 0.8 0.8 0.08 1 3
# 4.9 3.3 0.05 0.8 0.8 0.08 1 3
# -0.4 0.6 0.05 0.8 0.8 0.08 1 3
# 4.5 -0.8 0.05 0.8 0.8 0.08 1 3
# ...

# %%
#ENVIRONMENT TYPE 3
# type-1-resources: 5 type-2-resources: 5 type-3-resources: 5 type-4-resources: 5 type-5-resources: 30 
import random
print("Resources positions: starting...")
line = ""
x = 0
y = 0
isOv = True
typeCounter = 1
for i in range( 1, 51 ):
    
    while(isOv):
        x = round(random.uniform(-9.5, 9.5),1)
        y = round(random.uniform(-7.5, 9.5),1)
        if (typeCounter == 1):
            x_min = x - 0.04
            x_max = x + 0.04
            y_min = y - 0.04
            y_max = y + 0.04
        if (typeCounter == 2):
            x_min = x - 0.25
            x_max = x + 0.25
            y_min = y - 0.25
            y_max = y + 0.25
        if (typeCounter == 3):
            x_min = x - 0.45
            x_max = x + 0.45
            y_min = y - 0.45
            y_max = y + 0.45
        if (typeCounter == 4):
            x_min = x - 0.45
            x_max = x + 0.45
            y_min = y - 0.45
            y_max = y + 0.45
        if (typeCounter == 5):
            x = round(random.uniform(-9.2, 9.2),1)
            y = round(random.uniform(-7.5, 9.2),1)
            x_min = x - 0.6
            x_max = x + 0.6
            y_min = y - 0.6
            y_max = y + 0.6
        isCheck = True
        for j in range(len(x_p)):
            inrange_x = False
            inrange_y = False;
            if (j < 100):
                if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                    inrange_x = True
                if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                    inrange_y = True
            else:
                if (((x_p[j]-0.5) <= x_min and (x_p[j] + 0.5) >= x_max) or ((x_p[j]-0.5) >= x_min and (x_p[j] - 0.5) <= x_max) or ((x_p[j]+0.5) >= x_min and (x_p[j] + 0.5) <= x_max) ):
                    inrange_x = True
                if (((y_p[j]-0.5) <= y_min and (y_p[j] + 0.5) >= y_max) or ((y_p[j]-0.5) >= y_min and (y_p[j] - 0.5) <= y_max) or ((y_p[j]+0.5) >= y_min and (y_p[j] + 0.5) <= y_max) ):
                    inrange_y = True
            if (inrange_y and inrange_x):
                isCheck = False;
                break;
        if (isCheck == True):
            x_p.append(x)
            y_p.append(y)
            break
    if (typeCounter == 1):
        line = line + str(x) + " " + str(y) + " 0.05 0.08 0.08 0.08 0.002 " + str(typeCounter)+ "\n"
    if (typeCounter == 2):
        line = line + str(x) + " " + str(y) + " 0.05 0.5 0.5 0.08 0.8 " + str(typeCounter)+ "\n"
    if (typeCounter == 3):
        line = line + str(x) + " " + str(y) + " 0.05 0.8 0.8 0.08 1 " + str(typeCounter)+ "\n"
    if (typeCounter == 4):
        line = line + str(x) + " " + str(y) + " 0.05 1 1 0.08 1.2 " + str(typeCounter)+ "\n"
    if (typeCounter == 5):
        line = line + str(x) + " " + str(y) + " 0.05 1.2 1.2 0.08 1.4 " + str(typeCounter)+ "\n"
    if (typeCounter == 1 and i%30 == 0):
        typeCounter = typeCounter+1
    if (i%5 == 0 and typeCounter != 5):
        typeCounter = typeCounter+1
line = line.rstrip("\n")
print (line)
f = open("resources-environment-3.txt", "w")
f.write(line)
f.close()
print ("done")
# Out:
# Resources positions: starting...
# 0.7 -2.4 0.05 0.08 0.08 0.08 0.002 1
# 8.3 6.2 0.05 0.08 0.08 0.08 0.002 1
# 8.5 8.3 0.05 0.08 0.08 0.08 0.002 1
# 2.9 4.8 0.05 0.08 0.08 0.08 0.002 1
# 4.4 4.2 0.05 0.08 0.08 0.08 0.002 1
# 3.5 2.2 0.05 0.5 0.5 0.08 0.8 2
# 5.3 6.0 0.05 0.5 0.5 0.08 0.8 2
# -0.4 3.3 0.05 0.5 0.5 0.08 0.8 2
# 4.7 1.2 0.05 0.5 0.5 0.08 0.8 2
# -5.4 7.1 0.05 0.5 0.5 0.08 0.8 2
# -6.4 -0.5 0.05 0.8 0.8 0.08 1 3
# -2.3 1.8 0.05 0.8 0.8 0.08 1 3
# -4.0 5.6 0.05 0.8 0.8 0.08 1 3
# -9.1 -1.7 0.05 0.8 0.8 0.08 1 3
# 0.5 -6.7 0.05 0.8 0.8 0.08 1 3
# -0.7 4.9 0.05 1 1 0.08 1.2 4
# 8.8 4.9 0.05 1 1 0.08 1.2 4
# 1.0 7.8 0.05 1 1 0.08 1.2 4
# 5.1 9.0 0.05 1 1 0.08 1.2 4
# -3.5 8.8 0.05 1 1 0.08 1.2 4
# -5.2 0.3 0.05 1.2 1.2 0.08 1.4 5
# -0.5 -2.0 0.05 1.2 1.2 0.08 1.4 5
# 7.0 -1.0 0.05 1.2 1.2 0.08 1.4 5
# 0.9 9.2 0.05 1.2 1.2 0.08 1.4 5
# 6.2 4.4 0.05 1.2 1.2 0.08 1.4 5
# -4.2 -4.9 0.05 1.2 1.2 0.08 1.4 5
# -3.5 1.7 0.05 1.2 1.2 0.08 1.4 5
# -0.7 -4.0 0.05 1.2 1.2 0.08 1.4 5
# ...

# %%
from tempfile import mkstemp
from shutil import move, copymode
from os import fdopen, remove
def genRobotPositions(run):
    print("starting for iteration " + str(run))
    line = ""
    x = 0
    y = 0
    isOv = True
    x_p = []
    y_p = []
    for i in range(101):
        while(isOv):
            x = round(random.uniform(-9.7, 9.7),1)
            y = round(random.uniform(-7.5, 9.7),1)
            x_min = x - 0.1
            x_max = x + 0.1
            y_min = y - 0.1
            y_max = y + 0.1
            isCheck = True
            for j in range(len(x_p)):
                inrange_x = False
                inrange_y = False;
                if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                    inrange_x = True
                if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                    inrange_y = True
                if (inrange_y and inrange_x):
                    isCheck = False;
                    break;
            if (isCheck == True):
                x_p.append(x)
                y_p.append(y)
                break

        line = line + str(x) + " " + str(y) + " 0\n"
    line = line.rstrip("\n")
    filename = "robots-environment-3-run-" + str(run) + ".txt" 
    f = open(filename, "w")
    f.write(line)
    f.close()
    print ("done for iteration " + str(run))
    return x_p, y_p, filename
    
def environment1(run, x_p, y_p):
    #ENVIRONMENT TYPE 1
    # type-1-resources: 20 type-2-resources: 20 type-3-resources: 10 
    print("Resources positions: starting for environment 1 - run " + str(run))
    line = ""
    x = 0
    y = 0
    isOv = True
    typeCounter = 1
    for i in range( 1, 51 ):

        while(isOv):
            x = round(random.uniform(-9.5, 9.5),1)
            y = round(random.uniform(-7.5, 9.5),1)
            if (typeCounter == 1):
                x_min = x - 0.04
                x_max = x + 0.04
                y_min = y - 0.04
                y_max = y + 0.04
            if (typeCounter == 2):
                x_min = x - 0.25
                x_max = x + 0.25
                y_min = y - 0.25
                y_max = y + 0.25
            if (typeCounter == 3):
                x_min = x - 0.45
                x_max = x + 0.45
                y_min = y - 0.45
                y_max = y + 0.45
            if (typeCounter == 4):
                x_min = x - 0.45
                x_max = x + 0.45
                y_min = y - 0.45
                y_max = y + 0.45
            if (typeCounter == 5):
                x = round(random.uniform(-9.2, 9.2),1)
                y = round(random.uniform(-4.5, 9.2),1)
                x_min = x - 0.6
                x_max = x + 0.6
                y_min = y - 0.6
                y_max = y + 0.6
            isCheck = True
            for j in range(len(x_p)):
                inrange_x = False
                inrange_y = False;
                if (j < 100):
                    if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                        inrange_x = True
                    if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                        inrange_y = True
                else:
                    if (((x_p[j]-0.5) <= x_min and (x_p[j] + 0.5) >= x_max) or ((x_p[j]-0.5) >= x_min and (x_p[j] - 0.5) <= x_max) or ((x_p[j]+0.5) >= x_min and (x_p[j] + 0.5) <= x_max) ):
                        inrange_x = True
                    if (((y_p[j]-0.5) <= y_min and (y_p[j] + 0.5) >= y_max) or ((y_p[j]-0.5) >= y_min and (y_p[j] - 0.5) <= y_max) or ((y_p[j]+0.5) >= y_min and (y_p[j] + 0.5) <= y_max) ):
                        inrange_y = True
                if (inrange_y and inrange_x):
                    isCheck = False;
                    break;
            if (isCheck == True):
                x_p.append(x)
                y_p.append(y)
                break
        if (typeCounter == 1):
            line = line + str(x) + " " + str(y) + " 0.05 0.08 0.08 0.08 0.002 " + str(typeCounter)+ "\n"
        if (typeCounter == 2):
            line = line + str(x) + " " + str(y) + " 0.05 0.5 0.5 0.08 0.8 " + str(typeCounter)+ "\n"
        if (typeCounter == 3):
            line = line + str(x) + " " + str(y) + " 0.05 0.8 0.8 0.08 1 " + str(typeCounter)+ "\n"
        if (typeCounter == 4):
            line = line + str(x) + " " + str(y) + " 0.05 1 1 0.08 1.2 " + str(typeCounter)+ "\n"
        if (typeCounter == 5):
            line = line + str(x) + " " + str(y) + " 0.05 1.2 1.2 0.08 1.4 " + str(typeCounter)+ "\n"
        if (typeCounter == 1 and i%30 == 0):
            typeCounter = typeCounter+1
        if (typeCounter != 1 and i%5 == 0 and i != 30):
            typeCounter = typeCounter+1
    line = line.rstrip("\n")
    filename = "resources-environment-1-run-" + str(run) + ".txt" 
    f = open(filename, "w")
    f.write(line)
    f.close()
    print ("done")
    return filename
    
def environment2(run, x_p, y_p):
    #ENVIRONMENT TYPE 2
    # type-1-resources: 10 type-2-resources: 10 type-3-resources: 10 type-4-resources: 10 type-5-resources: 10 
    print("Resources positions: starting for environment 2 - run " + str(run))
    line = ""
    x = 0
    y = 0
    isOv = True
    typeCounter = 1
    for i in range( 1, 51 ):

        while(isOv):
            x = round(random.uniform(-9.5, 9.5),1)
            y = round(random.uniform(-7.5, 9.5),1)
            if (typeCounter == 1):
                x_min = x - 0.04
                x_max = x + 0.04
                y_min = y - 0.04
                y_max = y + 0.04
            if (typeCounter == 2):
                x_min = x - 0.25
                x_max = x + 0.25
                y_min = y - 0.25
                y_max = y + 0.25
            if (typeCounter == 3):
                x_min = x - 0.45
                x_max = x + 0.45
                y_min = y - 0.45
                y_max = y + 0.45
            if (typeCounter == 4):
                x_min = x - 0.45
                x_max = x + 0.45
                y_min = y - 0.45
                y_max = y + 0.45
            if (typeCounter == 5):
                x = round(random.uniform(-9.2, 9.2),1)
                y = round(random.uniform(-7.5, 9.2),1)
                x_min = x - 0.6
                x_max = x + 0.6
                y_min = y - 0.6
                y_max = y + 0.6
            isCheck = True
            for j in range(len(x_p)):
                inrange_x = False
                inrange_y = False;
                if (j < 100):
                    if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                        inrange_x = True
                    if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                        inrange_y = True
                else:
                    if (((x_p[j]-0.5) <= x_min and (x_p[j] + 0.5) >= x_max) or ((x_p[j]-0.5) >= x_min and (x_p[j] - 0.5) <= x_max) or ((x_p[j]+0.5) >= x_min and (x_p[j] + 0.5) <= x_max) ):
                        inrange_x = True
                    if (((y_p[j]-0.5) <= y_min and (y_p[j] + 0.5) >= y_max) or ((y_p[j]-0.5) >= y_min and (y_p[j] - 0.5) <= y_max) or ((y_p[j]+0.5) >= y_min and (y_p[j] + 0.5) <= y_max) ):
                        inrange_y = True
                if (inrange_y and inrange_x):
                    isCheck = False;
                    break;
            if (isCheck == True):
                x_p.append(x)
                y_p.append(y)
                break
        if (typeCounter == 1):
            line = line + str(x) + " " + str(y) + " 0.05 0.08 0.08 0.08 0.002 " + str(typeCounter)+ "\n"
        if (typeCounter == 2):
            line = line + str(x) + " " + str(y) + " 0.05 0.5 0.5 0.08 0.8 " + str(typeCounter)+ "\n"
        if (typeCounter == 3):
            line = line + str(x) + " " + str(y) + " 0.05 0.8 0.8 0.08 1 " + str(typeCounter)+ "\n"
        if (typeCounter == 4):
            line = line + str(x) + " " + str(y) + " 0.05 1 1 0.08 1.2 " + str(typeCounter)+ "\n"
        if (typeCounter == 5):
            line = line + str(x) + " " + str(y) + " 0.05 1.2 1.2 0.08 1.4 " + str(typeCounter)+ "\n"
        if (i%10 == 0):
            typeCounter = typeCounter+1
    line = line.rstrip("\n")
    filename = "resources-environment-2-run-" + str(run) + ".txt" 
    f = open(filename, "w")
    f.write(line)
    f.close()
    print ("done")
    return filename

    
def environment3(run, x_p, y_p):
    #ENVIRONMENT TYPE 3
    # type-1-resources: 5 type-2-resources: 5 type-3-resources: 5 type-4-resources: 5 type-5-resources: 30 
    print("Resources positions: starting for environment 3 - run " + str(run))
    line = ""
    x = 0
    y = 0
    isOv = True
    typeCounter = 1
    for i in range( 1, 51 ):

        while(isOv):
            x = round(random.uniform(-9.5, 9.5),1)
            y = round(random.uniform(-7.5, 9.5),1)
            if (typeCounter == 1):
                x_min = x - 0.04
                x_max = x + 0.04
                y_min = y - 0.04
                y_max = y + 0.04
            if (typeCounter == 2):
                x_min = x - 0.25
                x_max = x + 0.25
                y_min = y - 0.25
                y_max = y + 0.25
            if (typeCounter == 3):
                x_min = x - 0.45
                x_max = x + 0.45
                y_min = y - 0.45
                y_max = y + 0.45
            if (typeCounter == 4):
                x_min = x - 0.45
                x_max = x + 0.45
                y_min = y - 0.45
                y_max = y + 0.45
            if (typeCounter == 5):
                x = round(random.uniform(-9.2, 9.2),1)
                y = round(random.uniform(-7.5, 9.2),1)
                x_min = x - 0.6
                x_max = x + 0.6
                y_min = y - 0.6
                y_max = y + 0.6
            isCheck = True
            for j in range(len(x_p)):
                inrange_x = False
                inrange_y = False;
                if (j < 100):
                    if (((x_p[j]-0.1) <= x_min and (x_p[j] + 0.1) >= x_max) or ((x_p[j]-0.1) >= x_min and (x_p[j] - 0.1) <= x_max) or ((x_p[j]+0.1) >= x_min and (x_p[j] + 0.1) <= x_max) ):
                        inrange_x = True
                    if (((y_p[j]-0.1) <= y_min and (y_p[j] + 0.1) >= y_max) or ((y_p[j]-0.1) >= y_min and (y_p[j] - 0.1) <= y_max) or ((y_p[j]+0.1) >= y_min and (y_p[j] + 0.1) <= y_max) ):
                        inrange_y = True
                else:
                    if (((x_p[j]-0.5) <= x_min and (x_p[j] + 0.5) >= x_max) or ((x_p[j]-0.5) >= x_min and (x_p[j] - 0.5) <= x_max) or ((x_p[j]+0.5) >= x_min and (x_p[j] + 0.5) <= x_max) ):
                        inrange_x = True
                    if (((y_p[j]-0.5) <= y_min and (y_p[j] + 0.5) >= y_max) or ((y_p[j]-0.5) >= y_min and (y_p[j] - 0.5) <= y_max) or ((y_p[j]+0.5) >= y_min and (y_p[j] + 0.5) <= y_max) ):
                        inrange_y = True
                if (inrange_y and inrange_x):
                    isCheck = False;
                    break;
            if (isCheck == True):
                x_p.append(x)
                y_p.append(y)
                break
        if (typeCounter == 1):
            line = line + str(x) + " " + str(y) + " 0.05 0.08 0.08 0.08 0.002 " + str(typeCounter)+ "\n"
        if (typeCounter == 2):
            line = line + str(x) + " " + str(y) + " 0.05 0.5 0.5 0.08 0.8 " + str(typeCounter)+ "\n"
        if (typeCounter == 3):
            line = line + str(x) + " " + str(y) + " 0.05 0.8 0.8 0.08 1 " + str(typeCounter)+ "\n"
        if (typeCounter == 4):
            line = line + str(x) + " " + str(y) + " 0.05 1 1 0.08 1.2 " + str(typeCounter)+ "\n"
        if (typeCounter == 5):
            line = line + str(x) + " " + str(y) + " 0.05 1.2 1.2 0.08 1.4 " + str(typeCounter)+ "\n"
        if (typeCounter == 1 and i%30 == 0):
            typeCounter = typeCounter+1
        if (i%5 == 0 and typeCounter != 5):
            typeCounter = typeCounter+1
    line = line.rstrip("\n")
    filename = "resources-environment-3-run-" + str(run) + ".txt" 
    f = open(filename, "w")
    f.write(line)
    f.close()
    print ("done")
    return filename

    
'''This function overwrites the content of a file by replacing matching patterns in the old file'''
'''Date 26-09-2020'''
'''Time 18:38'''

def replace(file_path, pattern, subst, newFilename):
    #Create temp file
    fh, abs_path = mkstemp()
    with fdopen(fh,'w') as new_file:
        with open(file_path) as old_file:
            for line in old_file:
                new_file.write(line.replace(pattern, subst))
    #Copy the file permissions from the old file to the new file
    copymode(file_path, abs_path)
    #Remove original file
    #remove(file_path)
    #Move new file
    move(abs_path, newFilename)

# %%
import random
for run in range (1, 21):
    x_p, y_p, robotsFilename = genRobotPositions(run)
    envFilename1 = environment3(run, x_p, y_p)
    robotsPattern = "startPositionConfigFile="
    robotsReplacement = "startPositionConfigFile=" + str(robotsFilename)
    resourcesPattern = "resourcesConfigFile="
    resourcesReplacement = "resourcesConfigFile=" + str(envFilename1)
    newFilename = "con"+str(run)+".txt"
    replace("con.txt", robotsPattern, robotsReplacement, newFilename)
    replace(newFilename, resourcesPattern, resourcesReplacement, newFilename)
# Out:
# starting for iteration 1
# done for iteration 1
# Resources positions: starting for environment 3 - run 1
# done
# starting for iteration 2
# done for iteration 2
# Resources positions: starting for environment 3 - run 2
# done
# starting for iteration 3
# done for iteration 3
# Resources positions: starting for environment 3 - run 3
# done
# starting for iteration 4
# done for iteration 4
# Resources positions: starting for environment 3 - run 4
# done
# starting for iteration 5
# done for iteration 5
# Resources positions: starting for environment 3 - run 5
# done
# starting for iteration 6
# done for iteration 6
# Resources positions: starting for environment 3 - run 6
# done
# starting for iteration 7
# done for iteration 7
# Resources positions: starting for environment 3 - run 7
# done
# starting for iteration 8
# done for iteration 8
# Resources positions: starting for environment 3 - run 8
# done
# starting for iteration 9
# done for iteration 9
# ...
